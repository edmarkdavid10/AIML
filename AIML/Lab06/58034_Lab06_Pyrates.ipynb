# %% [markdown]
# <a href="https://colab.research.google.com/github/edmarkdavid10/AIML/blob/main/AIML/Lab06/58034_Lab06_Pyrates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Purpose of the Dataset
# For the purpose of the Dataset, it is a type of dataset that was used to perform the perceptron, the wine data set is composed of the attributes of Alcohol, Malic acid, ash, Alcalinity of ash, Magnesium, Phenols, Flavanoids, Nonflavanoid phenols, Proanthocyanins, Color Intensity, Hue, the OD280/OD315 of dilluted wines and Proline. With those attributes the perceptron can classify the patterns of the dataset and classified them into the group depending on their attributes.
#
# \
# ##Needs statement
# Providing chemical analysis of wines provide understanding to the manufacturers regarding what are its characteristics that are lacking, should be added, and should be adjusted. In this case for instance, if the acidity of a particular wine is excessively high, tartaric and malic acids might be precipitated out of the juice. This dataset contains variables pertaining to the attributes of various wines will allow the manufacturing companies to have proper production and it would also be a proper dataset used to perform multiple variable classification using perceptron algorithm.
#
# \
# ##Significance of the Dataset
# The significance of the Dataset will greatly contribute the wine companies to determine the originality of wines so they can create or invent more wines that can help their market. In addition the significance of the Dataset to the researcher can help them to perform the perceptrons to classify the dataset and to know the patterns of the data or wine.
#
# \
# ###Dataset: Wine Data Set
# Source: “UCI Machine Learning Repository: Wine Data Set.” https://archive.ics.uci.edu/ml/datasets/wine?fbclid=IwAR36tCSKbsAJrl9Zui0eXWrdjyPDLKbIeoF4uKxCrPd4c6-40Bg3z7CZzmA (accessed Dec. 18, 2021).

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Wine.csv', encoding='utf=8')
df.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127  ...   .28  2.29  5.64  1.04  3.92  1065
# 0  1  13.20  1.78  2.14  11.2  100  ...  0.26  1.28  4.38  1.05  3.40  1050
# 1  1  13.16  2.36  2.67  18.6  101  ...  0.30  2.81  5.68  1.03  3.17  1185
# 2  1  14.37  1.95  2.50  16.8  113  ...  0.24  2.18  7.80  0.86  3.45  1480
# 3  1  13.24  2.59  2.87  21.0  118  ...  0.39  1.82  4.32  1.04  2.93   735
# 4  1  14.20  1.76  2.45  15.2  112  ...  0.34  1.97  6.75  1.05  2.85  1450
#
# [5 rows x 14 columns]

# %%
df.columns = [  'name'
                 ,'alcohol'
             	,'malicAcid'
             	,'ash'
            	,'ashalcalinity'
             	,'magnesium'
            	,'totalPhenols'
             	,'flavanoids'
             	,'nonFlavanoidPhenols'
             	,'proanthocyanins'
            	,'colorIntensity'
             	,'hue'
             	,'od280_od315'
             	,'proline'
                ]

# %%
df.head(2)
# Out:
#    name  alcohol  malicAcid   ash  ...  colorIntensity   hue  od280_od315  proline
# 0     1    13.20       1.78  2.14  ...            4.38  1.05         3.40     1050
# 1     1    13.16       2.36  2.67  ...            5.68  1.03         3.17     1185
#
# [2 rows x 14 columns]

# %%
df.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize = (10,10))
sns.heatmap(corrmat, ax=ax, cmap='YlGnBu', linewidths = 0.1, annot = True)

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['name'], axis=1)
y = df['name']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2, shuffle=True)

print(x_train.shape)
print(x_test.shape)
# Out:
# (123, 13)
# (54, 13)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# #**Perceptron**

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
ppn = Perceptron()
ppn.fit(x_train, y_train)
ppn_predict = ppn.predict(x_test)
ppn_accuracy = accuracy_score(y_test, ppn_predict)
mse = mean_squared_error(y_test, ppn_predict)
mae = mean_absolute_error(y_test, ppn_predict)
pre = precision_score(y_test, ppn_predict, average='weighted')
rec = recall_score(y_test, ppn_predict, average='weighted')
print("Accuracy Score=", ppn_accuracy)
print("Mean Square Error=", mse)
print("Mean Absolute Score=", mae)
print("Precision Score =", pre)
print("Recall Score=", rec)
# Out:
# Accuracy Score= 0.9629629629629629
# Mean Square Error= 0.037037037037037035
# Mean Absolute Score= 0.037037037037037035
# Precision Score = 0.9664902998236331
# Recall Score= 0.9629629629629629
